# %% [markdown]
# # Support notebook for Basic Protocol 2
# # Annotate, normalize and feature select features for Single-Cell table.

# %%
import pandas as pd
import numpy as np
import pycytominer

# %% [markdown]
# # Inputs
#
# - Import metadata table containing the names of Compounds, MOAs, Concentrations, and Plate.
#
# - Import raw table as a dataframe (obtained in Samples_retrieval.ipynb notebook)

# %%
path = r'G:\.shortcut-targets-by-id\1KeRLnpHR83EZFglJAK4Lzvtpxq504dxs\2022_Fossa_Cruz_InterpretingProfiles'

# %%
metadata = pd.read_csv(path + r'\Notebooks\Metadata_SQ00015195.csv')

# %%
df_raw = pd.read_csv(path + r'\Data\backend\SingleCellRetrieving\SQ00015195_raw.csv')

# %%
df_raw.head()
# Out:
#   Image_Metadata_Well                       TableNumber  ImageNumber  \
# 0                 A02  1240fc906b760746bfaa4913fdb947b6           10
# 1                 A02  1240fc906b760746bfaa4913fdb947b6           10
# 2                 A02  1240fc906b760746bfaa4913fdb947b6           10
# 3                 A02  1240fc906b760746bfaa4913fdb947b6           10
# 4                 A02  1240fc906b760746bfaa4913fdb947b6           10
#
#    ObjectNumber  Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0             1                  7334                       642
# 1             2                  7084                      1952
# 2             3                 13696                      2159
# 3             4                  9814                      1123
# 4             5                 16297                      1672
#
#    Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                         0                     1.196197
# 1                         1                     1.288208
# 2                        40                     1.116869
# 3                        36                     1.147676
# 4                        78                     1.071092
#
#    Cells_AreaShape_Eccentricity  Cells_AreaShape_EulerNumber  ...  \
# 0                      0.732293                            1  ...
# 1                      0.865021                            1  ...
# 2                      0.632134                            1  ...
# 3                      0.773804                            1  ...
# 4                      0.708822                            1  ...
#
#    Image_Width_IllumAGP  Image_Width_IllumDNA  Image_Width_IllumER  \
# 0                  2160                  2160                 2160
# 1                  2160                  2160                 2160
# 2                  2160                  2160                 2160
# 3                  2160                  2160                 2160
# 4                  2160                  2160                 2160
#
#    Image_Width_IllumMito  Image_Width_IllumRNA  Image_Width_OrigAGP  \
# 0                   2160                  2160                 2160
# 1                   2160                  2160                 2160
# 2                   2160                  2160                 2160
# 3                   2160                  2160                 2160
# 4                   2160                  2160                 2160
#
#    Image_Width_OrigDNA  Image_Width_OrigER  Image_Width_OrigMito  \
# 0                 2160                2160                  2160
# 1                 2160                2160                  2160
# 2                 2160                2160                  2160
# 3                 2160                2160                  2160
# 4                 2160                2160                  2160
#
#    Image_Width_OrigRNA
# 0                 2160
# 1                 2160
# 2                 2160
# 3                 2160
# 4                 2160
#
# [5 rows x 2442 columns]

# %% [markdown]
# # Annotate table using metadata information

# %%
df = pycytominer.annotate(profiles = df_raw, platemap = metadata, join_on =  ["Metadata_Well", "Image_Metadata_Well"])

# %%
df.head()
# Out:
#    Metadata_Concentration Metadata_moa Metadata_Compound Metadata_Well  \
# 0                     0.0         DMSO              DMSO           A02
# 1                     0.0         DMSO              DMSO           A02
# 2                     0.0         DMSO              DMSO           A02
# 3                     0.0         DMSO              DMSO           A02
# 4                     0.0         DMSO              DMSO           A02
#
#   Metadata_Plate                       TableNumber  ImageNumber  ObjectNumber  \
# 0     SQ00015195  1240fc906b760746bfaa4913fdb947b6           10             1
# 1     SQ00015195  1240fc906b760746bfaa4913fdb947b6           10             2
# 2     SQ00015195  1240fc906b760746bfaa4913fdb947b6           10             3
# 3     SQ00015195  1240fc906b760746bfaa4913fdb947b6           10             4
# 4     SQ00015195  1240fc906b760746bfaa4913fdb947b6           10             5
#
#    Cells_AreaShape_Area  Cells_AreaShape_Center_X  ...  Image_Width_IllumAGP  \
# 0                  7334                       642  ...                  2160
# 1                  7084                      1952  ...                  2160
# 2                 13696                      2159  ...                  2160
# 3                  9814                      1123  ...                  2160
# 4                 16297                      1672  ...                  2160
#
#    Image_Width_IllumDNA  Image_Width_IllumER  Image_Width_IllumMito  \
# 0                  2160                 2160                   2160
# 1                  2160                 2160                   2160
# 2                  2160                 2160                   2160
# 3                  2160                 2160                   2160
# 4                  2160                 2160                   2160
#
#    Image_Width_IllumRNA  Image_Width_OrigAGP  Image_Width_OrigDNA  \
# 0                  2160                 2160                 2160
# 1                  2160                 2160                 2160
# 2                  2160                 2160                 2160
# 3                  2160                 2160                 2160
# 4                  2160                 2160                 2160
#
#    Image_Width_OrigER  Image_Width_OrigMito  Image_Width_OrigRNA
# 0                2160                  2160                 2160
# 1                2160                  2160                 2160
# 2                2160                  2160                 2160
# 3                2160                  2160                 2160
# 4                2160                  2160                 2160
#
# [5 rows x 2445 columns]

# %% [markdown]
# # List columns to keep and select Location columns
#
# - Location columns can't be normalized, because their values are locations (in pixels) of the nuclei center across the images.
#
# - cols_keep are columns that we want to maintain, which will be used in the Basic Protocol 2 notebook.

# %%
#if you want to select specific columns just copy and paste here
cols_keep = ['Metadata_Plate', 'Image_FileName_OrigAGP',
             'Image_FileName_OrigDNA','Image_FileName_OrigER',
             'Image_FileName_OrigMito','Image_FileName_OrigRNA',
            'Metadata_Well', 'Metadata_Concentration',
             'Metadata_moa', 'Metadata_Compound', 'Image_Width_OrigDNA']

# %%
df_loc = df[['Nuclei_Location_Center_X', 'Nuclei_Location_Center_Y']]

# %%
df_norm = df.drop(columns=['Nuclei_Location_Center_X', 'Nuclei_Location_Center_Y'])

# %% [markdown]
# # Normalize features values
#
# - Normalize the feature values using mad_robustize. For more details https://carpenter-singh-lab.broadinstitute.org/blog/how-normalize-cell-painting-data

# %%
df_norm2 = pycytominer.normalize(df_norm, meta_features = cols_keep, samples = "Metadata_Compound == 'DMSO'", method='mad_robustize', mad_robustize_epsilon = 0)

# %%
df_all = pd.concat([df_norm2, df_loc], axis = 1) #join the location_columns with the normalized df

# %% [markdown]
# # Feature selection
#
# - Remove features based on operation methods below.

# %%
df_selected = pycytominer.feature_select(df_all, operation = ['correlation_threshold', 'variance_threshold', 'drop_na_columns', 'blocklist','drop_outliers'], outlier_cutoff = 500)

# %%
print('df shape before feature selection:', df_norm.shape, 'df shape after feature selection:', df_selected.shape)
print('Number of columns removed:', df_norm.shape[1] - df_selected.shape[1])
# Out:
# df shape before feature selection: (13895, 2443) df shape after feature selection: (13895, 763)
# Number of columns removed: 1680

# %% [markdown]
# # Export dataframe as csv file

# %%
df_selected.to_csv('BasicProtocols2_Example.csv')
